# %% [markdown]
# This is meant to test the ability to get the all user installed models and adjust them on the fly.

# %%
import ollama

# %%
models_info = ollama.list()

# %%
for model in models_info.models:
    print(model.model)
# Out:
# qwen3-embedding:4b
# phi4:latest

# %%
# print(type(models_info))
# Out:
# <class 'ollama._types.ListResponse'>
