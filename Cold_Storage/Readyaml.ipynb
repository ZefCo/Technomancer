# %%
import yaml
import pathlib
cwd = pathlib.Path.cwd()

# %%
settings_file = cwd / "Settings" / "UserOptions.yaml"
with open(settings_file, "r") as file:
    settings = yaml.safe_load(file)

settings
# Out:
# {'embedding_models': ['qwen3'],
#  'models': ['phi4'],
#  'rule_systems': ['AD&D',
#   'CoC',
#   'Coyote & Crow',
#   'D&D5e',
#   'Rifts',
#   'SR2',
#   'SR3',
#   'SR4',
#   'SR5']}

# %%
games = settings["rule_systems"]

games.sort()
games
# Out:
# ['AD&D', 'CoC', 'Coyote & Crow', 'D&D5e', 'Rifts', 'SR2', 'SR3', 'SR4', 'SR5']

# %%
something = "D&D"

# %%
something = something.lower()
something
# Out:
# 'd&d'

# %%
print(something[0:1])
# Out:
# d

# %%
ascii_something = f"{ord(something[0])}"
for c in something[1:len(something)]:
    ascii_something = f"{ascii_something}_{ord(c)}"

ascii_something
# Out:
# '100_38_100'

# %%
really_long = ""
for _ in range(513):
    really_long = f"{really_long}x"

print(len(really_long))

really_long_prime = really_long[:512]
print(len(really_long_prime))
# Out:
# 513
# 512
