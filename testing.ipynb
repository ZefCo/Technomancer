# %%
import ollama
import subprocess

# %%
# Fetch available models by parsing `ollama list` output
# def get_models():
result = subprocess.run(['ollama', 'list'], capture_output=True, text=True)
lines = result.stdout.strip().splitlines()[1:]  # Skip header line
models = [line.split()[0] for line in lines]  # Get model names from the first column
    # return models

# %%
models
# Out:
# ['qwen3-embedding:4b', 'phi4:latest']
